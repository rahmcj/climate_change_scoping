# %%
import xarray as xr
import pandas as pd
import numpy as np
import os
import geopandas as gpd
from shapely.geometry import mapping

# Setup input and output directories
input_folder_path = './humidity_data/raw_data/'
output_folder_path = './humidity/processed_data/'
california_boundary_file = 'California_County_Boundaries.geojson'

import xarray as xr
import matplotlib.pyplot as plt
import datetime
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import glob
import os
import pandas as pd
import rioxarray
import geopandas as gpd
from shapely.geometry import mapping
import numpy as np
from shapely.geometry import Point, Polygon

# for testing only 
#nc_file_path = 'MERRA2_400.inst1_2d_lfo_Nx.20150801.nc4.nc4'

# Check the path
base_directory = ".\wind_data"

# Use os.path.join define all the path
plots_directory = os.path.join(base_directory, "plots")
csv_directory = os.path.join(base_directory, "csv")
daily_csv_directory = os.path.join(csv_directory, "daily")
monthly_csv_directory = os.path.join(csv_directory, "monthly")
monthly_data_directory = os.path.join(base_directory, "raw", "monthly_data")
daily_data_directory = os.path.join(r"C:\Users\rache\wind_data\wind_data\humidity\daily_data", "*.nc4")
pro_monthly_data_directory = os.path.join(base_directory, "processed", "monthly_data")
pro_daily_data_directory = os.path.join(base_directory, "processed", "daily_data")

california_boundary_file = "California_County_Boundaries.geojson"


# Make sure directories exist
os.makedirs(plots_directory, exist_ok=True)
os.makedirs(csv_directory, exist_ok=True)
os.makedirs(daily_csv_directory, exist_ok=True)
os.makedirs(monthly_csv_directory, exist_ok=True)
os.makedirs(pro_daily_data_directory, exist_ok=True)
os.makedirs(pro_monthly_data_directory, exist_ok=True)
# Load California boundary
california_gdf = gpd.read_file(california_boundary_file)

# Define a function to retrieve files matching a specific pattern within a directory
def get_file_list_from_directory_glob(directory, pattern="*.nc4*"):
    return glob.glob(os.path.join(directory, pattern))

#wind_data = xr.open_dataset(nc_file_path)
#california_boundary_file = "California_County_Boundaries.geojson"
#california_gdf = gpd.read_file(california_boundary_file)

nc_file_path = get_file_list_from_directory_glob(daily_data_directory)

# Get the date_str
#date_str = ds['time'].dt.strftime('%Y-%m-%d').item()
# Get the date string
def date(cf_datetime):
    # Get the range beginning date from the attribute
    date_text = cf_datetime.RangeBeginningDate
    
    return date_text

#date_str = date(nc_file_path)
# Define a function to convert cftime.DatetimeJulian objects to standard datetime.datetime objects
#def convert_cftime_datetime(cf_datetime):
    #return datetime.datetime(cf_datetime.year, cf_datetime.month, cf_datetime.day,
                             #cf_datetime.hour, cf_datetime.minute, cf_datetime.second)
#date_str = date(wind_data)
# Function to clip data using California boundary
def clip_california_data(nc_file_path):
    ds = xr.open_dataset(nc_file_path)
    if 'time_bnds' in ds.variables:
        ds = ds.drop_vars('time_bnds')
    ds = ds.rio.write_crs("EPSG:4326")
    ds = ds.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
    california_geometry = [mapping(shp) for shp in california_gdf.geometry]
    clipped_ds = ds.rio.clip(california_geometry, ds.rio.crs)
    for var in clipped_ds.variables:
        if 'grid_mapping' in clipped_ds[var].attrs:
            del clipped_ds[var].attrs['grid_mapping']
    return clipped_ds


# To process wind data (monthly or daily)
def process_wind_data(file_list, save_directory, resolution='monthly'):
    if resolution == 'monthly':
        for file in file_list:
            #print(f"Processing file: {file}")  # Print the name of the file being processed
            # Clip data using California boundary
            clipped_ds = clip_california_data(file)
            #print(clipped_ds)
            # Save clipped data
            output_file = os.path.join(save_directory, os.path.basename(file))
            clipped_ds.to_netcdf(output_file)
        new_file_list_monthly = glob.glob(os.path.join(save_directory, "*.nc4"))
        for new_file in new_file_list_monthly:
            # Open the processed dataset
            data = xr.open_dataset(new_file)
            
            # Select the wind data
            wind_dataset = data['QLML'].isel(time=0)
            # Convert date to date_str

            date_str = wind_dataset.time.dt.strftime('%Y-%m-%d').values
            
            # convert to csv
            df = data.to_dataframe()

            # Drop NaN values
            df.dropna(subset=['QLML'], inplace=True)

            # Calculate the average wind speed
            average_wind_speed = df.groupby(['lat', 'lon'])['QLML'].mean()
            
            df_avg_wind_speed = average_wind_speed.reset_index()
            
            
            ####
            geometry = [Point(lon, lat) for lon, lat in zip(df_avg_wind_speed['lat'], df_avg_wind_speed['lon'])]
            gdf = gpd.GeoDataFrame(df_avg_wind_speed, geometry=geometry, crs="EPSG:4326")
            california = gpd.read_file(california_boundary_file)

            # Perform spatial join to filter points within California
            points_within_california = gpd.sjoin(gdf, california, how="inner", predicate='within')

            # Drop unnecessary columns after the join
            points_within_california = points_within_california.drop(columns=['index_right'])
            
            
            path_csv = os.path.join(monthly_csv_directory, f'{date_str}.csv')
            df_avg_wind_speed.to_csv(path_csv)
            print(f'=== {date_str}.csv saved ===')
            # Create and save the plot
            create_wind_plot(df_avg_wind_speed, date_str)
            
    elif resolution == 'daily':  # Process daily data
        for file in file_list:
            # Clip data using California boundary
            clipped_ds = clip_california_data(file)

            # Save clipped data
            output_file = os.path.join(save_directory, os.path.basename(file))
            clipped_ds.to_netcdf(output_file)

        new_file_list_daily = glob.glob(os.path.join(save_directory, "*.nc4"))

        for new_file in new_file_list_daily:
            # Open the dataset
            data = xr.open_dataset(new_file)

            # Select the wind data from data
            wind_dataset = data['QLML'].isel(time=0)
            
            # Get the date_str
            date_str = wind_dataset.time.dt.strftime('%Y-%m-%d').values

            # convert to dataframe
            df = data.to_dataframe()
            # Drop NaN values
            df.dropna(subset=['QLML'], inplace=True)
            
            # Calculate the average wind speed
            average_wind_speed = df.groupby(['lat', 'lon'])['QLML'].mean()
            
            df_avg_wind_speed = average_wind_speed.reset_index()
            
            
            # Get points for California
            geometry = [Point(lon, lat) for lon, lat in zip(df_avg_wind_speed['lat'], df_avg_wind_speed['lon'])]
            gdf = gpd.GeoDataFrame(df_avg_wind_speed, geometry=geometry, crs="EPSG:4326")
            california = gpd.read_file(california_boundary_file)

            # Perform spatial join to filter points within California
            points_within_california = gpd.sjoin(gdf, california, how="inner", predicate='within')

            # Drop unnecessary columns after the join
            points_within_california = points_within_california.drop(columns=['index_right'])
            
            
            path_csv = os.path.join(daily_csv_directory, f'{date_str}.csv')
            df_avg_wind_speed.to_csv(path_csv)
            print(f'=== {date_str}.csv saved ===')
            # Create and save the plot
            #create_wind_plot(df_avg_wind_speed, date_str)



# Define a function to create and save a wind plot
def create_wind_plot(wind_dataset, date_str, extent=[-125, -113, 32, 42]):
    # Create plot over California
    fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={"projection": ccrs.PlateCarree()})
    ax.add_feature(cfeature.STATES, zorder=3, linewidth=1.5, edgecolor='black')
    ax.set_extent([-110, -130, 30, 45], crs=ccrs.PlateCarree())
    im = ax.scatter(wind_dataset['lon'], wind_dataset['lat'], s=20, alpha=0.5, c=wind_dataset['SPEEDLML'], cmap='magma')
    
    # Add a colourbar
    cbar = plt.colorbar(im, ax=ax, label='Wind Speed (m/s)')

    # Set title and labels
    plt.title(f'Average wind speed on {date_str}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')


    # Save the file
    filename = f"{plots_directory}/wind_{date_str}.png"
    plt.savefig(filename, bbox_inches='tight')
    plt.close(fig)
    
# Get the file list
file_list_monthly = glob.glob(os.path.join(monthly_data_directory, "*.nc4"))
file_list_daily = glob.glob(os.path.join(r"C:\Users\rache\wind_data\wind_data\humidity\daily_data", "*.nc4*"))
nc_file_list = glob.glob(os.path.join(r"C:\Users\rache\wind_data\wind_data\humidity\daily_data", "*.nc4"))
# Process monthly wind data
process_wind_data(file_list_monthly, pro_monthly_data_directory, resolution='monthly')

# Process daily wind data
process_wind_data(file_list_daily, pro_daily_data_directory, resolution='daily')

print("Success")
# Out:
# === 2012-08-07.csv saved ===
# === 2012-08-08.csv saved ===
# === 2012-08-09.csv saved ===
# === 2012-08-10.csv saved ===
# === 2012-08-11.csv saved ===
# === 2012-08-12.csv saved ===
# === 2012-08-13.csv saved ===
# === 2012-08-14.csv saved ===
# === 2012-08-15.csv saved ===
# === 2012-08-16.csv saved ===
# === 2012-08-17.csv saved ===
# === 2012-08-18.csv saved ===
# === 2012-08-19.csv saved ===
# === 2012-08-20.csv saved ===
# === 2012-08-21.csv saved ===
# === 2012-08-22.csv saved ===
# === 2012-08-23.csv saved ===
# === 2012-08-24.csv saved ===
# === 2012-08-25.csv saved ===
# === 2012-08-26.csv saved ===
# === 2012-08-27.csv saved ===
# === 2012-08-28.csv saved ===
# === 2012-08-29.csv saved ===
# === 2012-08-30.csv saved ===
# === 2012-08-31.csv saved ===
# === 2012-09-01.csv saved ===
# === 2012-09-02.csv saved ===
# === 2012-09-03.csv saved ===
# === 2012-09-04.csv saved ===
# === 2012-09-05.csv saved ===
# === 2012-09-06.csv saved ===
# === 2012-09-07.csv saved ===
# === 2012-09-08.csv saved ===
# === 2012-09-09.csv saved ===
# === 2012-09-10.csv saved ===
# === 2012-09-11.csv saved ===
# === 2012-09-12.csv saved ===
# === 2012-09-13.csv saved ===
# === 2012-09-14.csv saved ===
# === 2012-09-15.csv saved ===
# === 2012-09-16.csv saved ===
# === 2012-09-17.csv saved ===
# === 2012-09-18.csv saved ===
# === 2012-09-19.csv saved ===
# === 2012-09-20.csv saved ===
# === 2012-09-21.csv saved ===
# === 2012-09-22.csv saved ===
# === 2012-09-23.csv saved ===
# === 2012-09-24.csv saved ===
# === 2012-09-25.csv saved ===
# === 2012-09-26.csv saved ===
# === 2012-09-27.csv saved ===
# === 2012-09-28.csv saved ===
# === 2012-09-29.csv saved ===
# === 2012-09-30.csv saved ===
# === 2012-10-01.csv saved ===
# === 2012-10-02.csv saved ===
# === 2012-10-03.csv saved ===
# === 2012-10-04.csv saved ===
# === 2012-10-05.csv saved ===
# === 2012-10-06.csv saved ===
# === 2012-10-07.csv saved ===
# === 2012-10-08.csv saved ===
# === 2012-10-09.csv saved ===
# === 2012-10-10.csv saved ===
# === 2012-10-11.csv saved ===
# === 2012-10-12.csv saved ===
# === 2012-10-13.csv saved ===
# === 2012-10-14.csv saved ===
# === 2012-10-15.csv saved ===
# === 2012-10-16.csv saved ===
# === 2012-10-17.csv saved ===
# === 2012-10-18.csv saved ===
# === 2012-10-19.csv saved ===
# === 2012-10-20.csv saved ===
# === 2012-10-21.csv saved ===
# === 2012-10-22.csv saved ===
# === 2012-10-23.csv saved ===
# === 2012-10-24.csv saved ===
# === 2012-10-25.csv saved ===
# === 2012-10-26.csv saved ===
# === 2012-10-27.csv saved ===
# === 2012-10-28.csv saved ===
# === 2012-10-29.csv saved ===
# === 2012-10-30.csv saved ===
# === 2012-10-31.csv saved ===
# === 2012-11-01.csv saved ===
# === 2012-11-02.csv saved ===
# === 2012-11-03.csv saved ===
# === 2012-11-04.csv saved ===
# === 2012-11-05.csv saved ===
# === 2012-11-06.csv saved ===
# === 2012-11-07.csv saved ===
# === 2012-11-08.csv saved ===
# === 2012-11-09.csv saved ===
# === 2012-11-10.csv saved ===
# === 2012-11-11.csv saved ===
# === 2012-11-12.csv saved ===
# === 2012-11-13.csv saved ===
# === 2012-11-14.csv saved ===
# === 2012-11-15.csv saved ===
# === 2012-11-16.csv saved ===
# === 2012-11-17.csv saved ===
# === 2012-11-18.csv saved ===
# === 2012-11-19.csv saved ===
# === 2012-11-20.csv saved ===
# === 2012-11-21.csv saved ===
# === 2012-11-22.csv saved ===
# === 2012-11-23.csv saved ===
# === 2012-11-24.csv saved ===
# === 2012-11-25.csv saved ===
# === 2012-11-26.csv saved ===
# === 2012-11-27.csv saved ===
# === 2012-11-28.csv saved ===
# === 2012-11-29.csv saved ===
# === 2012-11-30.csv saved ===
# === 2012-12-01.csv saved ===
# === 2012-12-02.csv saved ===
# === 2012-12-03.csv saved ===
# === 2012-12-04.csv saved ===
# === 2012-12-05.csv saved ===
# === 2012-12-06.csv saved ===
# === 2012-12-07.csv saved ===
# === 2012-12-08.csv saved ===
# === 2012-12-09.csv saved ===
# === 2012-12-10.csv saved ===
# === 2012-12-11.csv saved ===
# === 2012-12-12.csv saved ===
# === 2012-12-13.csv saved ===
# === 2012-12-14.csv saved ===
# === 2012-12-15.csv saved ===
# === 2012-12-16.csv saved ===
# === 2012-12-17.csv saved ===
# === 2012-12-18.csv saved ===
# === 2012-12-19.csv saved ===
# === 2012-12-20.csv saved ===
# === 2012-12-21.csv saved ===
# === 2012-12-22.csv saved ===
# === 2012-12-23.csv saved ===
# === 2012-12-24.csv saved ===
# === 2012-12-25.csv saved ===
# === 2012-12-26.csv saved ===
# === 2012-12-27.csv saved ===
# === 2012-12-28.csv saved ===
# === 2012-12-29.csv saved ===
# === 2012-12-30.csv saved ===
# === 2012-12-31.csv saved ===
# === 2013-01-01.csv saved ===
# === 2013-01-02.csv saved ===
# === 2013-01-03.csv saved ===
# === 2013-01-04.csv saved ===
# === 2013-01-05.csv saved ===
# === 2013-01-06.csv saved ===
# === 2013-01-07.csv saved ===
# === 2013-01-08.csv saved ===
# === 2013-01-09.csv saved ===
# === 2013-01-10.csv saved ===
# === 2013-01-11.csv saved ===
# === 2013-01-12.csv saved ===
# === 2013-01-13.csv saved ===
# === 2013-01-14.csv saved ===
# === 2013-01-15.csv saved ===
# === 2013-01-16.csv saved ===
# === 2013-01-17.csv saved ===
# === 2013-01-18.csv saved ===
# === 2013-01-19.csv saved ===
# === 2013-01-20.csv saved ===
# === 2013-01-21.csv saved ===
# === 2013-01-22.csv saved ===
# === 2013-01-23.csv saved ===
# === 2013-01-24.csv saved ===
# === 2013-01-25.csv saved ===
# === 2013-01-26.csv saved ===
# === 2013-01-27.csv saved ===
# === 2013-01-28.csv saved ===
# === 2013-01-29.csv saved ===
# === 2013-01-30.csv saved ===
# === 2013-01-31.csv saved ===
# === 2013-02-01.csv saved ===
# === 2013-02-02.csv saved ===
# === 2013-02-03.csv saved ===
# === 2013-02-04.csv saved ===
# === 2013-02-05.csv saved ===
# === 2013-02-06.csv saved ===
# === 2013-02-07.csv saved ===
# === 2013-02-08.csv saved ===
# === 2013-02-09.csv saved ===
# === 2013-02-10.csv saved ===
# === 2013-02-11.csv saved ===
# === 2013-02-12.csv saved ===
# === 2013-02-13.csv saved ===
# === 2013-02-14.csv saved ===
# === 2013-02-15.csv saved ===
# === 2013-02-16.csv saved ===
# === 2013-02-17.csv saved ===
# === 2013-02-18.csv saved ===
# === 2013-02-19.csv saved ===
# === 2013-02-20.csv saved ===
# === 2013-02-21.csv saved ===
# === 2013-02-22.csv saved ===
# === 2013-02-23.csv saved ===
# === 2013-02-24.csv saved ===
# === 2013-02-25.csv saved ===
# === 2013-02-26.csv saved ===
# === 2013-02-27.csv saved ===
# === 2013-02-28.csv saved ===
# === 2013-03-01.csv saved ===
# === 2013-03-02.csv saved ===
# === 2013-03-03.csv saved ===
# === 2013-03-04.csv saved ===
# === 2013-03-05.csv saved ===
# === 2013-03-06.csv saved ===
# === 2013-03-07.csv saved ===
# === 2013-03-08.csv saved ===
# === 2013-03-09.csv saved ===
# === 2013-03-10.csv saved ===
# === 2013-03-11.csv saved ===
# === 2013-03-12.csv saved ===
# === 2013-03-13.csv saved ===
# === 2013-03-14.csv saved ===
# === 2013-03-15.csv saved ===
# === 2013-03-16.csv saved ===
# === 2013-03-17.csv saved ===
# === 2013-03-18.csv saved ===
# === 2013-03-19.csv saved ===
# === 2013-03-20.csv saved ===
# === 2013-03-21.csv saved ===
# === 2013-03-22.csv saved ===
# === 2013-03-23.csv saved ===
# === 2013-03-24.csv saved ===
# === 2013-03-25.csv saved ===
# === 2013-03-26.csv saved ===
# === 2013-03-27.csv saved ===
# === 2013-03-28.csv saved ===
# === 2013-03-29.csv saved ===
# === 2013-03-30.csv saved ===
# === 2013-03-31.csv saved ===
# === 2013-04-01.csv saved ===
# === 2013-04-02.csv saved ===
# === 2013-04-03.csv saved ===
# === 2013-04-04.csv saved ===
# === 2013-04-05.csv saved ===
# === 2013-04-06.csv saved ===
# === 2013-04-07.csv saved ===
# === 2013-04-08.csv saved ===
# === 2013-04-09.csv saved ===
# === 2013-04-10.csv saved ===
# === 2013-04-11.csv saved ===
# === 2013-04-12.csv saved ===
# === 2013-04-13.csv saved ===
# === 2013-04-14.csv saved ===
# === 2013-04-15.csv saved ===
# === 2013-04-16.csv saved ===
# === 2013-04-17.csv saved ===
# === 2013-04-18.csv saved ===
# === 2013-04-19.csv saved ===
# === 2013-04-20.csv saved ===
# === 2013-04-21.csv saved ===
# === 2013-04-22.csv saved ===
# === 2013-04-23.csv saved ===
# === 2013-04-24.csv saved ===
# === 2013-04-25.csv saved ===
# === 2013-04-26.csv saved ===
# === 2013-04-27.csv saved ===
# === 2013-04-28.csv saved ===
# === 2013-04-29.csv saved ===
# === 2013-04-30.csv saved ===
# === 2013-05-01.csv saved ===
# === 2013-05-02.csv saved ===
# === 2013-05-03.csv saved ===
# === 2013-05-04.csv saved ===
# === 2013-05-05.csv saved ===
# === 2013-05-06.csv saved ===
# === 2013-05-07.csv saved ===
# === 2013-05-08.csv saved ===
# === 2013-05-09.csv saved ===
# === 2013-05-10.csv saved ===
# === 2013-05-11.csv saved ===
# === 2013-05-12.csv saved ===
# === 2013-05-13.csv saved ===
# === 2013-05-14.csv saved ===
# === 2013-05-15.csv saved ===
# === 2013-05-16.csv saved ===
# === 2013-05-17.csv saved ===
# === 2013-05-18.csv saved ===
# === 2013-05-19.csv saved ===
# === 2013-05-20.csv saved ===
# === 2013-05-21.csv saved ===
# === 2013-05-22.csv saved ===
# === 2013-05-23.csv saved ===
# === 2013-05-24.csv saved ===
# === 2013-05-25.csv saved ===
# === 2013-05-26.csv saved ===
# === 2013-05-27.csv saved ===
# === 2013-05-28.csv saved ===
# === 2013-05-29.csv saved ===
# === 2013-05-30.csv saved ===
# === 2013-05-31.csv saved ===
# === 2013-06-01.csv saved ===
# === 2013-06-02.csv saved ===
# === 2013-06-03.csv saved ===
# === 2013-06-04.csv saved ===
# === 2013-06-05.csv saved ===
# === 2013-06-06.csv saved ===
# === 2013-06-07.csv saved ===
# === 2013-06-08.csv saved ===
# === 2013-06-09.csv saved ===
# === 2013-06-10.csv saved ===
# === 2013-06-11.csv saved ===
# === 2013-06-12.csv saved ===
# === 2013-06-13.csv saved ===
# === 2013-06-14.csv saved ===
# === 2013-06-15.csv saved ===
# === 2013-06-16.csv saved ===
# === 2013-06-17.csv saved ===
# === 2013-06-18.csv saved ===
# === 2013-06-19.csv saved ===
# === 2013-06-20.csv saved ===
# === 2013-06-21.csv saved ===
# === 2013-06-22.csv saved ===
# === 2013-06-23.csv saved ===
# === 2013-06-24.csv saved ===
# === 2013-06-25.csv saved ===
# === 2013-06-26.csv saved ===
# === 2013-06-27.csv saved ===
# === 2013-06-28.csv saved ===
# === 2013-06-29.csv saved ===
# === 2013-06-30.csv saved ===
# === 2013-07-01.csv saved ===
# === 2013-07-02.csv saved ===
# === 2013-07-03.csv saved ===
# === 2013-07-04.csv saved ===
# === 2013-07-05.csv saved ===
# === 2013-07-06.csv saved ===
# === 2013-07-07.csv saved ===
# === 2013-07-08.csv saved ===
# === 2013-07-09.csv saved ===
# === 2013-07-10.csv saved ===
# === 2013-07-11.csv saved ===
# === 2013-07-12.csv saved ===
# === 2013-07-13.csv saved ===
# === 2013-07-14.csv saved ===
# === 2013-07-15.csv saved ===
# === 2013-07-16.csv saved ===
# === 2013-07-17.csv saved ===
# === 2013-07-18.csv saved ===
# === 2013-07-19.csv saved ===
# === 2013-07-20.csv saved ===
# === 2013-07-21.csv saved ===
# === 2013-07-22.csv saved ===
# === 2013-07-23.csv saved ===
# === 2013-07-24.csv saved ===
# === 2013-07-25.csv saved ===
# === 2013-07-26.csv saved ===
# === 2013-07-27.csv saved ===
# === 2013-07-28.csv saved ===
# === 2013-07-29.csv saved ===
# === 2013-07-30.csv saved ===
# === 2013-07-31.csv saved ===
# === 2013-08-01.csv saved ===
# === 2013-08-02.csv saved ===
# === 2013-08-03.csv saved ===
# === 2013-08-04.csv saved ===
# === 2013-08-05.csv saved ===
# === 2013-08-06.csv saved ===
# === 2013-08-07.csv saved ===
# === 2013-08-08.csv saved ===
# === 2013-08-09.csv saved ===
# === 2013-08-10.csv saved ===
# === 2013-08-11.csv saved ===
# === 2013-08-12.csv saved ===
# === 2013-08-13.csv saved ===
# === 2013-08-14.csv saved ===
# === 2013-08-15.csv saved ===
# === 2013-08-16.csv saved ===
# === 2013-08-17.csv saved ===
# === 2013-08-18.csv saved ===
# === 2013-08-19.csv saved ===
# === 2013-08-20.csv saved ===
# === 2013-08-21.csv saved ===
# === 2013-08-22.csv saved ===
# === 2013-08-23.csv saved ===
# === 2013-08-24.csv saved ===
# === 2013-08-25.csv saved ===
# === 2013-08-26.csv saved ===
# === 2013-08-27.csv saved ===
# === 2013-08-28.csv saved ===
# === 2013-08-29.csv saved ===
# === 2013-08-30.csv saved ===
# === 2013-08-31.csv saved ===
# === 2013-09-01.csv saved ===
# === 2013-09-02.csv saved ===
# === 2013-09-03.csv saved ===
# === 2013-09-04.csv saved ===
# === 2013-09-05.csv saved ===
# === 2013-09-06.csv saved ===
# === 2013-09-07.csv saved ===
# === 2013-09-08.csv saved ===
# === 2013-09-09.csv saved ===
# === 2013-09-10.csv saved ===
# === 2013-09-11.csv saved ===
# === 2013-09-12.csv saved ===
# === 2013-09-13.csv saved ===
# === 2013-09-14.csv saved ===
# === 2013-09-15.csv saved ===
# === 2013-09-16.csv saved ===
# === 2013-09-17.csv saved ===
# === 2013-09-18.csv saved ===
# === 2013-09-19.csv saved ===
# === 2013-09-20.csv saved ===
# === 2013-09-21.csv saved ===
# === 2013-09-22.csv saved ===
# === 2013-09-23.csv saved ===
# === 2013-09-24.csv saved ===
# === 2013-09-25.csv saved ===
# === 2013-09-26.csv saved ===
# === 2013-09-27.csv saved ===
# === 2013-09-28.csv saved ===
# === 2013-09-29.csv saved ===
# === 2013-09-30.csv saved ===
# === 2013-10-01.csv saved ===
# === 2013-10-02.csv saved ===
# === 2013-10-03.csv saved ===
# === 2013-10-04.csv saved ===
# === 2013-10-05.csv saved ===
# === 2013-10-06.csv saved ===
# === 2013-10-07.csv saved ===
# === 2013-10-08.csv saved ===
# === 2013-10-09.csv saved ===
# === 2013-10-10.csv saved ===
# === 2013-10-11.csv saved ===
# === 2013-10-12.csv saved ===
# === 2013-10-13.csv saved ===
# === 2013-10-14.csv saved ===
# === 2013-10-15.csv saved ===
# === 2013-10-16.csv saved ===
# === 2013-10-17.csv saved ===
# === 2013-10-18.csv saved ===
# === 2013-10-19.csv saved ===
# === 2013-10-20.csv saved ===
# === 2013-10-21.csv saved ===
# === 2013-10-22.csv saved ===
# === 2013-10-23.csv saved ===
# === 2013-10-24.csv saved ===
# === 2013-10-25.csv saved ===
# === 2013-10-26.csv saved ===
# === 2013-10-27.csv saved ===
# === 2013-10-28.csv saved ===
# === 2013-10-29.csv saved ===
# === 2013-10-30.csv saved ===
# === 2013-10-31.csv saved ===
# === 2013-11-01.csv saved ===
# === 2013-11-02.csv saved ===
# === 2013-11-03.csv saved ===
# === 2013-11-04.csv saved ===
# === 2013-11-05.csv saved ===
# === 2013-11-06.csv saved ===
# === 2013-11-07.csv saved ===
# === 2013-11-08.csv saved ===
# === 2013-11-09.csv saved ===
# === 2013-11-10.csv saved ===
# === 2013-11-11.csv saved ===
# === 2013-11-12.csv saved ===
# === 2013-11-13.csv saved ===
# === 2013-11-14.csv saved ===
# === 2013-11-15.csv saved ===
# === 2013-11-16.csv saved ===
# === 2013-11-17.csv saved ===
# === 2013-11-18.csv saved ===
# === 2013-11-19.csv saved ===
# === 2013-11-20.csv saved ===
# === 2013-11-21.csv saved ===
# === 2013-11-22.csv saved ===
# === 2013-11-23.csv saved ===
# === 2013-11-24.csv saved ===
# === 2013-11-25.csv saved ===
# === 2013-11-26.csv saved ===
# === 2013-11-27.csv saved ===
# === 2013-11-28.csv saved ===
# === 2013-11-29.csv saved ===
# === 2013-11-30.csv saved ===
# === 2013-12-01.csv saved ===
# === 2013-12-02.csv saved ===
# === 2013-12-03.csv saved ===
# === 2013-12-04.csv saved ===
# === 2013-12-05.csv saved ===
# === 2013-12-06.csv saved ===
# === 2013-12-07.csv saved ===
# === 2013-12-08.csv saved ===
# === 2013-12-09.csv saved ===
# === 2013-12-10.csv saved ===
# === 2013-12-11.csv saved ===
# === 2013-12-12.csv saved ===
# === 2013-12-13.csv saved ===
# === 2013-12-14.csv saved ===
# === 2013-12-15.csv saved ===
# === 2013-12-16.csv saved ===
# === 2013-12-17.csv saved ===
# === 2013-12-18.csv saved ===
# === 2013-12-19.csv saved ===
# === 2013-12-20.csv saved ===
# === 2013-12-21.csv saved ===
# === 2013-12-22.csv saved ===
# === 2013-12-23.csv saved ===
# === 2013-12-24.csv saved ===
# === 2013-12-25.csv saved ===
# === 2013-12-26.csv saved ===
# === 2013-12-27.csv saved ===
# === 2013-12-28.csv saved ===
# === 2013-12-29.csv saved ===
# === 2013-12-30.csv saved ===
# === 2013-12-31.csv saved ===
# === 2014-01-01.csv saved ===
# === 2014-01-02.csv saved ===
# === 2014-01-03.csv saved ===
# === 2014-01-04.csv saved ===
# === 2014-01-05.csv saved ===
# === 2014-01-06.csv saved ===
# === 2014-01-07.csv saved ===
# === 2014-01-08.csv saved ===
# === 2014-01-09.csv saved ===
# === 2014-01-10.csv saved ===
# === 2014-01-11.csv saved ===
# === 2014-01-12.csv saved ===
# === 2014-01-13.csv saved ===
# === 2014-01-14.csv saved ===
# === 2014-01-15.csv saved ===
# === 2014-01-16.csv saved ===
# === 2014-01-17.csv saved ===
# === 2014-01-18.csv saved ===
# === 2014-01-19.csv saved ===
# === 2014-01-20.csv saved ===
# Success

# %%
# renaming humidity field to match subsequent processes for streamlit

import pandas as pd
import os

# Directory containing the CSV files
directory = r"C:\Users\rache\wind_data\wind_data\csv\daily"

# New name
new_name = 'Qair_f_inst'

# Iterate over each CSV file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        filepath = os.path.join(directory, filename)
        
        
        df = pd.read_csv(filepath)
        
        # Rename the column
        df.rename(columns={'QLML': new_name}, inplace=True)
        
        # Save the DataFrame back to a CSV file
        df.to_csv(filepath, index=False)
